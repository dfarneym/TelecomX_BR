# %% [markdown]
# # 📌 Extracão

# %%
# Importando as bibliotecas
import pandas as pd
import numpy as np

# %%
# Carregando a api dos dados
df = pd.read_json('TelecomX_Data.json')
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
# Normalizar os dados e expandindo eles
df_dados_normalizados = pd.concat([
    df.drop(columns=['customer', 'phone', 'internet','account']),
    pd.json_normalize(df['customer']),
    pd.json_normalize(df['phone']),
    pd.json_normalize(df['internet']),
    pd.json_normalize(df['account']),
], axis=1)

# Dicionários de mapeamento para as traduções
map_churn = {'Yes': 'Sim', 'No': 'Não'}
map_gender = {'Female': 'Feminino', 'Male': 'Masculino'}
map_partner = {'Yes': 'Sim', 'No': 'Não'}
map_dependents = {'Yes': 'Sim', 'No': 'Não'}
map_phone_service = {'Yes': 'Sim', 'No': 'Não'}
map_multiple_lines = {'No phone service': 'Sem serviço telefônico', 'No': 'Não', 'Yes': 'Sim'}
map_internet_service = {'DSL': 'DSL', 'Fiber optic': 'Fibra ótica', 'No': 'Não'}
map_online_security = {'No internet service': 'Sem serviço de internet', 'No': 'Não', 'Yes': 'Sim'}
map_online_backup = {'No internet service': 'Sem serviço de internet', 'No': 'Não', 'Yes': 'Sim'}
map_device_protection = {'No internet service': 'Sem serviço de internet', 'No': 'Não', 'Yes': 'Sim'}
map_tech_support = {'No internet service': 'Sem serviço de internet', 'No': 'Não', 'Yes': 'Sim'}
map_streaming_tv =  {'No internet service': 'Sem serviço de internet', 'No': 'Não', 'Yes': 'Sim'}
map_streaming_movies =  {'No internet service': 'Sem serviço de internet', 'No': 'Não', 'Yes': 'Sim'}
map_contract = {'Month-to-month': 'Mês a mês', 'One year': 'Um ano', 'Two year': 'Dois anos'}
map_paperless_billing = {'Yes': 'Sim', 'No': 'Não'}
map_payment_method = {'Electronic check': 'Cheque eletrônico', 'Mailed check': 'Cheque por correio', 'Bank transfer (automatic)': 'Transferência bancária (automática)', 'Credit card (automatic)': 'Cartão de crédito (automático)'}

# Aplicar as traduções
df_dados_normalizados['Churn'] = df_dados_normalizados['Churn'].replace(map_churn)
df_dados_normalizados['gender'] = df_dados_normalizados['gender'].replace(map_gender)
df_dados_normalizados['Partner'] = df_dados_normalizados['Partner'].replace(map_partner)
df_dados_normalizados['Dependents'] = df_dados_normalizados['Dependents'].replace(map_dependents)
df_dados_normalizados['PhoneService'] = df_dados_normalizados['PhoneService'].replace(map_phone_service)
df_dados_normalizados['MultipleLines'] = df_dados_normalizados['MultipleLines'].replace(map_multiple_lines)
df_dados_normalizados['InternetService'] = df_dados_normalizados['InternetService'].replace(map_internet_service)
df_dados_normalizados['OnlineSecurity'] = df_dados_normalizados['OnlineSecurity'].replace(map_online_security)
df_dados_normalizados['OnlineBackup'] = df_dados_normalizados['OnlineBackup'].replace(map_online_backup)
df_dados_normalizados['DeviceProtection'] = df_dados_normalizados['DeviceProtection'].replace(map_device_protection)
df_dados_normalizados['TechSupport'] = df_dados_normalizados['TechSupport'].replace(map_tech_support)
df_dados_normalizados['StreamingTV'] = df_dados_normalizados['StreamingTV'].replace(map_streaming_tv)
df_dados_normalizados['StreamingMovies'] = df_dados_normalizados['StreamingMovies'].replace(map_streaming_movies)
df_dados_normalizados['Contract'] = df_dados_normalizados['Contract'].replace(map_contract)
df_dados_normalizados['PaperlessBilling'] = df_dados_normalizados['PaperlessBilling'].replace(map_paperless_billing)
df_dados_normalizados['PaymentMethod'] = df_dados_normalizados['PaymentMethod'].replace(map_payment_method)

# Exibir os valores únicos das colunas traduzidas para verificação
print("\nValores únicos após tradução:")
for coluna in ['Churn', 'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']:
    print(f"\nColuna: {coluna}")
    print(df_dados_normalizados[coluna].unique())

# Definir o mapa de renomeação
mapa_de_nomes = {
 'customerID': 'ID_Cliente',
    'Churn': 'Cancelou',
    'gender': 'Genero',
    'SeniorCitizen': 'Idoso',
    'Partner': 'Possui_Conjuge',
    'Dependents': 'Possui_Dependentes',
    'tenure': 'Meses_Permanencia',
    'PhoneService': 'Servico_Telefone',
    'MultipleLines': 'Multiplas_Linhas',
    'InternetService': 'Tipo_Internet',
    'OnlineBackup': 'Backup_Online',
    'DeviceProtection': 'Protecao_Dispositivo',
    'TechSupport': 'Suporte_Tecnico',
    'StreamingTV': 'Streaming_TV',
    'StreamingMovies': 'Streaming_Filmes',
    'Contract': 'Tipo_Contrato',
    'PaperlessBilling': 'Fatura_Digital',
    'PaymentMethod': 'Metodo_Pagamento',
    'Charges.Monthly': 'Cobranca_Mensal',
    'Charges.Total': 'Cobranca_Total'   

}

# Renomear imediatamente
df_final = df_dados_normalizados.rename(columns=mapa_de_nomes)

# 4. Verificar o resultado
df_final.head()
# Out:
# Valores únicos após tradução:
#
# Coluna: Churn
# ['Não' 'Sim' '']
#
# Coluna: gender
# ['Feminino' 'Masculino']
#
# Coluna: Partner
# ['Sim' 'Não']
#
# Coluna: Dependents
# ['Sim' 'Não']
#
# Coluna: PhoneService
# ['Sim' 'Não']
#
# Coluna: MultipleLines
# ['Não' 'Sim' 'Sem serviço telefônico']
#
# Coluna: InternetService
# ['DSL' 'Fibra ótica' 'Não']
#
# Coluna: OnlineSecurity
# ['Não' 'Sim' 'Sem serviço de internet']
#
# Coluna: OnlineBackup
# ['Sim' 'Não' 'Sem serviço de internet']
#
# Coluna: DeviceProtection
# ['Não' 'Sim' 'Sem serviço de internet']
#
# Coluna: TechSupport
# ['Sim' 'Não' 'Sem serviço de internet']
#
# Coluna: StreamingTV
# ['Sim' 'Não' 'Sem serviço de internet']
#
# Coluna: StreamingMovies
# ['Não' 'Sim' 'Sem serviço de internet']
#
# Coluna: Contract
# ['Um ano' 'Mês a mês' 'Dois anos']
#
# Coluna: PaperlessBilling
# ['Sim' 'Não']
#
# Coluna: PaymentMethod
# ['Cheque por correio' 'Cheque eletrônico'
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Cliente            7267 non-null   object
#  1   Cancelou              7267 non-null   object
#  2   Genero                7267 non-null   object
#  3   Idoso                 7267 non-null   int64
#  4   Possui_Conjuge        7267 non-null   object
#  5   Possui_Dependentes    7267 non-null   object
#  6   Meses_Permanencia     7267 non-null   int64
#  7   Servico_Telefone      7267 non-null   object
#  8   Multiplas_Linhas      7267 non-null   object
#  9   Tipo_Internet         7267 non-null   object
#  10  OnlineSecurity        7267 non-null   object
#  11  Backup_Online         7267 non-null   object
#  12  Protecao_Dispositivo  7267 non-null   object
#  13  Suporte_Tecnico       7267 non-null   object
#  14  Streaming_TV          7267 non-null   object
# ...

# %% [markdown]
# # 🔧 Transformação

# %%
# Fazendo Verificação de dados duplicados
id_duplicados = df_final.ID_Cliente.duplicated().sum()
print(f"\nNúmero total de linhas duplicadas: {id_duplicados}")
# Out:
# Número total de linhas duplicadas: 0

# %%
# Verificando valores nulos
print("\nContagem de valores nulos por coluna:")
print(df_final.isnull().sum())
# Out:
# Contagem de valores nulos por coluna:
# ID_Cliente               0
# Cancelou                 0
# Genero                   0
# Idoso                    0
# Possui_Conjuge           0
# Possui_Dependentes       0
# Meses_Permanencia        0
# Servico_Telefone         0
# Multiplas_Linhas         0
# Tipo_Internet            0
# OnlineSecurity           0
# Backup_Online            0
# Protecao_Dispositivo     0
# Suporte_Tecnico          0
# Streaming_TV             0
# Streaming_Filmes         0
# Tipo_Contrato            0
# Fatura_Digital           0
# Metodo_Pagamento         0
# Cobranca_Mensal          0
# Cobranca_Total          11
# dtype: int64

# %%
# Salvando arquivo df_final já tratado em csv
df_final.to_csv("TelecomX_data_tratados.csv", index=False)

# %%
# Mudando o tipo de Object para Numero
selecionando_colunas = ['Meses_Permanencia','Cobranca_Mensal','Cobranca_Total']
df_final[selecionando_colunas]=df_final[selecionando_colunas].apply(pd.to_numeric, errors='coerce')
print("\nDataFrame final com todas as colunas convertidas:")
print(df_final[['Meses_Permanencia','Cobranca_Mensal','Cobranca_Total']])
print("\nTipos de dados finais:")
print(df_final.dtypes)
# Out:
# DataFrame final com todas as colunas convertidas:
#       Meses_Permanencia  Cobranca_Mensal  Cobranca_Total
# 0                     9            65.60          593.30
# 1                     9            59.90          542.40
# 2                     4            73.90          280.85
# 3                    13            98.00         1237.85
# 4                     3            83.90          267.40
# ...                 ...              ...             ...
# 7262                 13            55.15          742.90
# 7263                 22            85.10         1873.70
# 7264                  2            50.30           92.75
# 7265                 67            67.85         4627.65
# 7266                 63            59.00         3707.60
#
# [7267 rows x 3 columns]
#
# Tipos de dados finais:
# ID_Cliente               object
# Cancelou                 object
# Genero                   object
# Idoso                     int64
# Possui_Conjuge           object
# ...

# %%
df_final.head()
# Out:
#    ID_Cliente Cancelou     Genero  Idoso Possui_Conjuge Possui_Dependentes  \
# 0  0002-ORFBO      Não   Feminino      0            Sim                Sim
# 1  0003-MKNFE      Não  Masculino      0            Não                Não
# 2  0004-TLHLJ      Sim  Masculino      0            Não                Não
# 3  0011-IGKFF      Sim  Masculino      1            Sim                Não
# 4  0013-EXCHZ      Sim   Feminino      1            Sim                Não
#
#    Meses_Permanencia Servico_Telefone Multiplas_Linhas Tipo_Internet  ...  \
# 0                  9              Sim              Não           DSL  ...
# 1                  9              Sim              Sim           DSL  ...
# 2                  4              Sim              Não   Fibra ótica  ...
# 3                 13              Sim              Não   Fibra ótica  ...
# 4                  3              Sim              Não   Fibra ótica  ...
#
#   Backup_Online Protecao_Dispositivo Suporte_Tecnico Streaming_TV  \
# ...

# %%
# Salvando arquivo df_final já tratado em json
df_final.to_json("TelecomX_data_tratados.json")

# %% [markdown]
# #📊 Carga e análise

# %% [markdown]
# #📄Relatorio Final
